# %% [markdown]
# # --> Importations

# %%
# !pip install opencv-python
import pickle
import cv2
import os
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: opencv-python in c:\users\karna\anaconda3\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\karna\anaconda3\lib\site-packages (from opencv-python) (1.19.2)

# %% [markdown]
# # --> Pickel save

# %%
X = [3, 2, 1]
y = [2, 4, 1]

pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

# %% [markdown]
# # --> Pickel load

# %%
pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)
print(X[2])
# Out:
# 1

# %% [markdown]
# # --> C2V image processing

# %%
path = "crvor.png"
img_array = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.imshow(img_array, cmap="gray")
plt.show()

# %% [markdown]
# # --> CV2 resizing

# %%
IMG_SIZE = 50
resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(resized, cmap="gray")
plt.show()
